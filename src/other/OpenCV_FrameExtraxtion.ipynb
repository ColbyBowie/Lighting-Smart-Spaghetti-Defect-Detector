# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\colby\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\colby\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
import sys
from pathlib import Path

# 1. Specify the input directory containing videos and the output directory for frames
input_dir = Path("../data/raw/H2D_Data/TimeLapses")  # <-- Change this to your videos directory
output_dir = Path("../data/raw/H2D_Data/Frames")     # <-- Change this to your desired output folder

# 2. Create the output directory if it doesn't exist
if not output_dir.exists():
    output_dir.mkdir(parents=True, exist_ok=True)
    print(f"[INFO] Created output directory: {output_dir}")
else:
    print(f"[INFO] Using existing output directory: {output_dir}")
    
    
# 3. Get a list of all .mp4 and .avi files in the input directory
video_paths = list(input_dir.glob("*.mp4")) + list(input_dir.glob("*.avi"))
if not video_paths:
    print(f"[ERROR] No .mp4 or .avi files found in {input_dir}")
else:
    print(f"[INFO] Found {len(video_paths)} videos to process.")

# 4. Iterate through each video and extract every N-th frame
desired_fps = 10  # <-- Change this to extract at a different frame rate (frames per second)

for video_path in video_paths:
    video_name = video_path.stem  # Base name without extension, e.g., "my_video"
    print(f"\n[PROCESSING] Video: {video_path.name}")

    # Open the video capture
    vid = cv2.VideoCapture(str(video_path))
    if not vid.isOpened():
        print(f"[ERROR] Could not open video file: {video_path}")
        continue
    else:
        print(f"[OK] Opened video: {video_path.name}")

    # Determine original FPS to calculate step size
    orig_fps = vid.get(cv2.CAP_PROP_FPS)
    if orig_fps <= 0:
        print(f"[WARNING] Could not determine FPS for {video_path.name}. Defaulting to step=1.")
        step = 1
    else:
        step = int(orig_fps // desired_fps) if orig_fps >= desired_fps else 1
        print(f"[INFO] Original FPS: {orig_fps:.2f}, Step size: {step}")

    frame_idx = 0
    saved_idx = 0

    while True:
        ret, frame = vid.read()
        if not ret:
            print(f"[INFO] No more frames at index {frame_idx}.")
            break

        if frame_idx % step == 0:
            # Build the filename: <video_name>_frame_<6-digit index>.jpg
            out_filename = f"{video_name}_frame_{saved_idx:06d}.jpg"
            out_path = output_dir / out_filename

            success = cv2.imwrite(str(out_path), frame)
            if success:
                print(f"[OK] Saved {out_filename}")
                saved_idx += 1
            else:
                print(f"[ERROR] Failed to save {out_filename}")

        frame_idx += 1

    # Release the video capture handle
    vid.release()
    print(f"[DONE] {video_name}: Total frames read: {frame_idx}, frames saved: {saved_idx}")

print("\n[COMPLETE] All videos have been processed.")
# Out:
# [INFO] Using existing output directory: ..\data\raw\H2D_Data\Frames
# [INFO] Found 2 videos to process.
#
# [PROCESSING] Video: Daylight4.mp4
# [OK] Opened video: Daylight4.mp4
# [INFO] Original FPS: 24.05, Step size: 2
# [OK] Saved Daylight4_frame_000000.jpg
# [OK] Saved Daylight4_frame_000001.jpg
# [OK] Saved Daylight4_frame_000002.jpg
# [OK] Saved Daylight4_frame_000003.jpg
# [OK] Saved Daylight4_frame_000004.jpg
# [OK] Saved Daylight4_frame_000005.jpg
# [OK] Saved Daylight4_frame_000006.jpg
# [OK] Saved Daylight4_frame_000007.jpg
# [OK] Saved Daylight4_frame_000008.jpg
# [OK] Saved Daylight4_frame_000009.jpg
# [OK] Saved Daylight4_frame_000010.jpg
# [OK] Saved Daylight4_frame_000011.jpg
# [OK] Saved Daylight4_frame_000012.jpg
# [OK] Saved Daylight4_frame_000013.jpg
# [OK] Saved Daylight4_frame_000014.jpg
# [OK] Saved Daylight4_frame_000015.jpg
# [OK] Saved Daylight4_frame_000016.jpg
# [OK] Saved Daylight4_frame_000017.jpg
# [OK] Saved Daylight4_frame_000018.jpg
# [OK] Saved Daylight4_frame_000019.jpg
# [OK] Saved Daylight4_frame_000020.jpg
# [OK] Saved Daylight4_frame_000021.jpg
# [OK] Saved Daylight4_frame_000022.jpg
# [OK] Saved Daylight4_frame_000023.jpg
# [OK] Saved Daylight4_frame_000024.jpg
# [OK] Saved Daylight4_frame_000025.jpg
# [OK] Saved Daylight4_frame_000026.jpg
# [OK] Saved Daylight4_frame_000027.jpg
# [OK] Saved Daylight4_frame_000028.jpg
# [OK] Saved Daylight4_frame_000029.jpg
# [OK] Saved Daylight4_frame_000030.jpg
# [OK] Saved Daylight4_frame_000031.jpg
# [OK] Saved Daylight4_frame_000032.jpg
# [OK] Saved Daylight4_frame_000033.jpg
# [OK] Saved Daylight4_frame_000034.jpg
# [OK] Saved Daylight4_frame_000035.jpg
# [OK] Saved Daylight4_frame_000036.jpg
# [OK] Saved Daylight4_frame_000037.jpg
# [OK] Saved Daylight4_frame_000038.jpg
# [OK] Saved Daylight4_frame_000039.jpg
# [OK] Saved Daylight4_frame_000040.jpg
# [OK] Saved Daylight4_frame_000041.jpg
# [OK] Saved Daylight4_frame_000042.jpg
# [OK] Saved Daylight4_frame_000043.jpg
# [OK] Saved Daylight4_frame_000044.jpg
# [OK] Saved Daylight4_frame_000045.jpg
# [OK] Saved Daylight4_frame_000046.jpg
# [OK] Saved Daylight4_frame_000047.jpg
# [OK] Saved Daylight4_frame_000048.jpg
# [OK] Saved Daylight4_frame_000049.jpg
# [OK] Saved Daylight4_frame_000050.jpg
# [OK] Saved Daylight4_frame_000051.jpg
# [OK] Saved Daylight4_frame_000052.jpg
# [OK] Saved Daylight4_frame_000053.jpg
# [OK] Saved Daylight4_frame_000054.jpg
# [OK] Saved Daylight4_frame_000055.jpg
# [OK] Saved Daylight4_frame_000056.jpg
# [OK] Saved Daylight4_frame_000057.jpg
# [OK] Saved Daylight4_frame_000058.jpg
# [OK] Saved Daylight4_frame_000059.jpg
# [OK] Saved Daylight4_frame_000060.jpg
# [OK] Saved Daylight4_frame_000061.jpg
# [OK] Saved Daylight4_frame_000062.jpg
# [OK] Saved Daylight4_frame_000063.jpg
# [OK] Saved Daylight4_frame_000064.jpg
# [OK] Saved Daylight4_frame_000065.jpg
# [OK] Saved Daylight4_frame_000066.jpg
# [OK] Saved Daylight4_frame_000067.jpg
# [OK] Saved Daylight4_frame_000068.jpg
# [OK] Saved Daylight4_frame_000069.jpg
# [OK] Saved Daylight4_frame_000070.jpg
# [OK] Saved Daylight4_frame_000071.jpg
# [OK] Saved Daylight4_frame_000072.jpg
# [OK] Saved Daylight4_frame_000073.jpg
# [OK] Saved Daylight4_frame_000074.jpg
# [OK] Saved Daylight4_frame_000075.jpg
# [OK] Saved Daylight4_frame_000076.jpg
# [OK] Saved Daylight4_frame_000077.jpg
# [OK] Saved Daylight4_frame_000078.jpg
# [OK] Saved Daylight4_frame_000079.jpg
# [OK] Saved Daylight4_frame_000080.jpg
# [OK] Saved Daylight4_frame_000081.jpg
# [OK] Saved Daylight4_frame_000082.jpg
# [OK] Saved Daylight4_frame_000083.jpg
# [OK] Saved Daylight4_frame_000084.jpg
# [OK] Saved Daylight4_frame_000085.jpg
# [OK] Saved Daylight4_frame_000086.jpg
# [OK] Saved Daylight4_frame_000087.jpg
# [OK] Saved Daylight4_frame_000088.jpg
# [OK] Saved Daylight4_frame_000089.jpg
# [OK] Saved Daylight4_frame_000090.jpg
# [OK] Saved Daylight4_frame_000091.jpg
# [OK] Saved Daylight4_frame_000092.jpg
# [OK] Saved Daylight4_frame_000093.jpg
# [OK] Saved Daylight4_frame_000094.jpg
# [OK] Saved Daylight4_frame_000095.jpg
# [OK] Saved Daylight4_frame_000096.jpg
# [OK] Saved Daylight4_frame_000097.jpg
# [OK] Saved Daylight4_frame_000098.jpg
# [OK] Saved Daylight4_frame_000099.jpg
# [OK] Saved Daylight4_frame_000100.jpg
# [OK] Saved Daylight4_frame_000101.jpg
# [OK] Saved Daylight4_frame_000102.jpg
# [OK] Saved Daylight4_frame_000103.jpg
# [OK] Saved Daylight4_frame_000104.jpg
# [OK] Saved Daylight4_frame_000105.jpg
# [OK] Saved Daylight4_frame_000106.jpg
# [OK] Saved Daylight4_frame_000107.jpg
# [OK] Saved Daylight4_frame_000108.jpg
# [OK] Saved Daylight4_frame_000109.jpg
# [OK] Saved Daylight4_frame_000110.jpg
# [OK] Saved Daylight4_frame_000111.jpg
# [OK] Saved Daylight4_frame_000112.jpg
# [OK] Saved Daylight4_frame_000113.jpg
# [OK] Saved Daylight4_frame_000114.jpg
# [OK] Saved Daylight4_frame_000115.jpg
# [OK] Saved Daylight4_frame_000116.jpg
# [OK] Saved Daylight4_frame_000117.jpg
# [OK] Saved Daylight4_frame_000118.jpg
# [OK] Saved Daylight4_frame_000119.jpg
# [OK] Saved Daylight4_frame_000120.jpg
# [OK] Saved Daylight4_frame_000121.jpg
# [OK] Saved Daylight4_frame_000122.jpg
# [OK] Saved Daylight4_frame_000123.jpg
# [OK] Saved Daylight4_frame_000124.jpg
# [OK] Saved Daylight4_frame_000125.jpg
# [OK] Saved Daylight4_frame_000126.jpg
# [OK] Saved Daylight4_frame_000127.jpg
# [OK] Saved Daylight4_frame_000128.jpg
# [OK] Saved Daylight4_frame_000129.jpg
# [OK] Saved Daylight4_frame_000130.jpg
# [OK] Saved Daylight4_frame_000131.jpg
# [OK] Saved Daylight4_frame_000132.jpg
# [OK] Saved Daylight4_frame_000133.jpg
# [OK] Saved Daylight4_frame_000134.jpg
# [OK] Saved Daylight4_frame_000135.jpg
# [OK] Saved Daylight4_frame_000136.jpg
# [OK] Saved Daylight4_frame_000137.jpg
# [OK] Saved Daylight4_frame_000138.jpg
# [OK] Saved Daylight4_frame_000139.jpg
# [OK] Saved Daylight4_frame_000140.jpg
# [OK] Saved Daylight4_frame_000141.jpg
# [OK] Saved Daylight4_frame_000142.jpg
# [OK] Saved Daylight4_frame_000143.jpg
# [OK] Saved Daylight4_frame_000144.jpg
# [OK] Saved Daylight4_frame_000145.jpg
# [OK] Saved Daylight4_frame_000146.jpg
# [OK] Saved Daylight4_frame_000147.jpg
# [OK] Saved Daylight4_frame_000148.jpg
# [OK] Saved Daylight4_frame_000149.jpg
# [OK] Saved Daylight4_frame_000150.jpg
# [OK] Saved Daylight4_frame_000151.jpg
# [OK] Saved Daylight4_frame_000152.jpg
# [OK] Saved Daylight4_frame_000153.jpg
# [OK] Saved Daylight4_frame_000154.jpg
# [OK] Saved Daylight4_frame_000155.jpg
# [OK] Saved Daylight4_frame_000156.jpg
# [OK] Saved Daylight4_frame_000157.jpg
# [OK] Saved Daylight4_frame_000158.jpg
# [OK] Saved Daylight4_frame_000159.jpg
# [OK] Saved Daylight4_frame_000160.jpg
# [OK] Saved Daylight4_frame_000161.jpg
# [OK] Saved Daylight4_frame_000162.jpg
# [OK] Saved Daylight4_frame_000163.jpg
# [OK] Saved Daylight4_frame_000164.jpg
# [OK] Saved Daylight4_frame_000165.jpg
# [OK] Saved Daylight4_frame_000166.jpg
# [OK] Saved Daylight4_frame_000167.jpg
# [OK] Saved Daylight4_frame_000168.jpg
# [OK] Saved Daylight4_frame_000169.jpg
# [OK] Saved Daylight4_frame_000170.jpg
# [OK] Saved Daylight4_frame_000171.jpg
# [OK] Saved Daylight4_frame_000172.jpg
# [OK] Saved Daylight4_frame_000173.jpg
# [OK] Saved Daylight4_frame_000174.jpg
# [OK] Saved Daylight4_frame_000175.jpg
# [OK] Saved Daylight4_frame_000176.jpg
# [OK] Saved Daylight4_frame_000177.jpg
# [OK] Saved Daylight4_frame_000178.jpg
# [OK] Saved Daylight4_frame_000179.jpg
# [OK] Saved Daylight4_frame_000180.jpg
# [OK] Saved Daylight4_frame_000181.jpg
# [OK] Saved Daylight4_frame_000182.jpg
# [OK] Saved Daylight4_frame_000183.jpg
# [OK] Saved Daylight4_frame_000184.jpg
# [OK] Saved Daylight4_frame_000185.jpg
# [OK] Saved Daylight4_frame_000186.jpg
# [OK] Saved Daylight4_frame_000187.jpg
# [OK] Saved Daylight4_frame_000188.jpg
# [OK] Saved Daylight4_frame_000189.jpg
# [OK] Saved Daylight4_frame_000190.jpg
# [OK] Saved Daylight4_frame_000191.jpg
# [OK] Saved Daylight4_frame_000192.jpg
# [OK] Saved Daylight4_frame_000193.jpg
# [OK] Saved Daylight4_frame_000194.jpg
# [OK] Saved Daylight4_frame_000195.jpg
# [OK] Saved Daylight4_frame_000196.jpg
# [OK] Saved Daylight4_frame_000197.jpg
# [OK] Saved Daylight4_frame_000198.jpg
# [OK] Saved Daylight4_frame_000199.jpg
# [OK] Saved Daylight4_frame_000200.jpg
# [OK] Saved Daylight4_frame_000201.jpg
# [OK] Saved Daylight4_frame_000202.jpg
# [OK] Saved Daylight4_frame_000203.jpg
# [OK] Saved Daylight4_frame_000204.jpg
# [OK] Saved Daylight4_frame_000205.jpg
# [OK] Saved Daylight4_frame_000206.jpg
# [OK] Saved Daylight4_frame_000207.jpg
# [OK] Saved Daylight4_frame_000208.jpg
# [OK] Saved Daylight4_frame_000209.jpg
# [OK] Saved Daylight4_frame_000210.jpg
# [OK] Saved Daylight4_frame_000211.jpg
# [OK] Saved Daylight4_frame_000212.jpg
# [OK] Saved Daylight4_frame_000213.jpg
# [OK] Saved Daylight4_frame_000214.jpg
# [OK] Saved Daylight4_frame_000215.jpg
# [OK] Saved Daylight4_frame_000216.jpg
# [OK] Saved Daylight4_frame_000217.jpg
# [OK] Saved Daylight4_frame_000218.jpg
# [OK] Saved Daylight4_frame_000219.jpg
# [OK] Saved Daylight4_frame_000220.jpg
# [OK] Saved Daylight4_frame_000221.jpg
# [OK] Saved Daylight4_frame_000222.jpg
# [OK] Saved Daylight4_frame_000223.jpg
# [OK] Saved Daylight4_frame_000224.jpg
# [OK] Saved Daylight4_frame_000225.jpg
# [OK] Saved Daylight4_frame_000226.jpg
# [OK] Saved Daylight4_frame_000227.jpg
# [OK] Saved Daylight4_frame_000228.jpg
# [OK] Saved Daylight4_frame_000229.jpg
# [OK] Saved Daylight4_frame_000230.jpg
# [OK] Saved Daylight4_frame_000231.jpg
# [OK] Saved Daylight4_frame_000232.jpg
# [OK] Saved Daylight4_frame_000233.jpg
# [OK] Saved Daylight4_frame_000234.jpg
# [OK] Saved Daylight4_frame_000235.jpg
# [OK] Saved Daylight4_frame_000236.jpg
# [OK] Saved Daylight4_frame_000237.jpg
# [OK] Saved Daylight4_frame_000238.jpg
# [OK] Saved Daylight4_frame_000239.jpg
# [OK] Saved Daylight4_frame_000240.jpg
# [OK] Saved Daylight4_frame_000241.jpg
# [OK] Saved Daylight4_frame_000242.jpg
# [OK] Saved Daylight4_frame_000243.jpg
# [OK] Saved Daylight4_frame_000244.jpg
# [OK] Saved Daylight4_frame_000245.jpg
# [OK] Saved Daylight4_frame_000246.jpg
# [OK] Saved Daylight4_frame_000247.jpg
# [OK] Saved Daylight4_frame_000248.jpg
# [OK] Saved Daylight4_frame_000249.jpg
# [OK] Saved Daylight4_frame_000250.jpg
# [OK] Saved Daylight4_frame_000251.jpg
# [OK] Saved Daylight4_frame_000252.jpg
# [OK] Saved Daylight4_frame_000253.jpg
# [OK] Saved Daylight4_frame_000254.jpg
# [OK] Saved Daylight4_frame_000255.jpg
# [OK] Saved Daylight4_frame_000256.jpg
# [OK] Saved Daylight4_frame_000257.jpg
# [OK] Saved Daylight4_frame_000258.jpg
# [OK] Saved Daylight4_frame_000259.jpg
# [INFO] No more frames at index 520.
# [DONE] Daylight4: Total frames read: 520, frames saved: 260
#
# [PROCESSING] Video: Shoplight8.mp4
# [OK] Opened video: Shoplight8.mp4
# [INFO] Original FPS: 24.06, Step size: 2
# [OK] Saved Shoplight8_frame_000000.jpg
# [OK] Saved Shoplight8_frame_000001.jpg
# [OK] Saved Shoplight8_frame_000002.jpg
# [OK] Saved Shoplight8_frame_000003.jpg
# [OK] Saved Shoplight8_frame_000004.jpg
# [OK] Saved Shoplight8_frame_000005.jpg
# [OK] Saved Shoplight8_frame_000006.jpg
# [OK] Saved Shoplight8_frame_000007.jpg
# [OK] Saved Shoplight8_frame_000008.jpg
# [OK] Saved Shoplight8_frame_000009.jpg
# [OK] Saved Shoplight8_frame_000010.jpg
# [OK] Saved Shoplight8_frame_000011.jpg
# [OK] Saved Shoplight8_frame_000012.jpg
# [OK] Saved Shoplight8_frame_000013.jpg
# [OK] Saved Shoplight8_frame_000014.jpg
# [OK] Saved Shoplight8_frame_000015.jpg
# [OK] Saved Shoplight8_frame_000016.jpg
# [OK] Saved Shoplight8_frame_000017.jpg
# [OK] Saved Shoplight8_frame_000018.jpg
# [OK] Saved Shoplight8_frame_000019.jpg
# [OK] Saved Shoplight8_frame_000020.jpg
# [OK] Saved Shoplight8_frame_000021.jpg
# [OK] Saved Shoplight8_frame_000022.jpg
# [OK] Saved Shoplight8_frame_000023.jpg
# [OK] Saved Shoplight8_frame_000024.jpg
# [OK] Saved Shoplight8_frame_000025.jpg
# [OK] Saved Shoplight8_frame_000026.jpg
# [OK] Saved Shoplight8_frame_000027.jpg
# [OK] Saved Shoplight8_frame_000028.jpg
# [OK] Saved Shoplight8_frame_000029.jpg
# [OK] Saved Shoplight8_frame_000030.jpg
# [OK] Saved Shoplight8_frame_000031.jpg
# [OK] Saved Shoplight8_frame_000032.jpg
# [OK] Saved Shoplight8_frame_000033.jpg
# [OK] Saved Shoplight8_frame_000034.jpg
# [OK] Saved Shoplight8_frame_000035.jpg
# [OK] Saved Shoplight8_frame_000036.jpg
# [OK] Saved Shoplight8_frame_000037.jpg
# [OK] Saved Shoplight8_frame_000038.jpg
# [OK] Saved Shoplight8_frame_000039.jpg
# [OK] Saved Shoplight8_frame_000040.jpg
# [OK] Saved Shoplight8_frame_000041.jpg
# [OK] Saved Shoplight8_frame_000042.jpg
# [OK] Saved Shoplight8_frame_000043.jpg
# [OK] Saved Shoplight8_frame_000044.jpg
# [OK] Saved Shoplight8_frame_000045.jpg
# [OK] Saved Shoplight8_frame_000046.jpg
# [OK] Saved Shoplight8_frame_000047.jpg
# [OK] Saved Shoplight8_frame_000048.jpg
# [OK] Saved Shoplight8_frame_000049.jpg
# [OK] Saved Shoplight8_frame_000050.jpg
# [OK] Saved Shoplight8_frame_000051.jpg
# [OK] Saved Shoplight8_frame_000052.jpg
# [OK] Saved Shoplight8_frame_000053.jpg
# [OK] Saved Shoplight8_frame_000054.jpg
# [OK] Saved Shoplight8_frame_000055.jpg
# [OK] Saved Shoplight8_frame_000056.jpg
# [OK] Saved Shoplight8_frame_000057.jpg
# [OK] Saved Shoplight8_frame_000058.jpg
# [OK] Saved Shoplight8_frame_000059.jpg
# [OK] Saved Shoplight8_frame_000060.jpg
# [OK] Saved Shoplight8_frame_000061.jpg
# [OK] Saved Shoplight8_frame_000062.jpg
# [OK] Saved Shoplight8_frame_000063.jpg
# [OK] Saved Shoplight8_frame_000064.jpg
# [OK] Saved Shoplight8_frame_000065.jpg
# [OK] Saved Shoplight8_frame_000066.jpg
# [OK] Saved Shoplight8_frame_000067.jpg
# [OK] Saved Shoplight8_frame_000068.jpg
# [OK] Saved Shoplight8_frame_000069.jpg
# [OK] Saved Shoplight8_frame_000070.jpg
# [OK] Saved Shoplight8_frame_000071.jpg
# [OK] Saved Shoplight8_frame_000072.jpg
# [OK] Saved Shoplight8_frame_000073.jpg
# [OK] Saved Shoplight8_frame_000074.jpg
# [OK] Saved Shoplight8_frame_000075.jpg
# [OK] Saved Shoplight8_frame_000076.jpg
# [OK] Saved Shoplight8_frame_000077.jpg
# [OK] Saved Shoplight8_frame_000078.jpg
# [OK] Saved Shoplight8_frame_000079.jpg
# [OK] Saved Shoplight8_frame_000080.jpg
# [OK] Saved Shoplight8_frame_000081.jpg
# [OK] Saved Shoplight8_frame_000082.jpg
# [OK] Saved Shoplight8_frame_000083.jpg
# [OK] Saved Shoplight8_frame_000084.jpg
# [OK] Saved Shoplight8_frame_000085.jpg
# [OK] Saved Shoplight8_frame_000086.jpg
# [OK] Saved Shoplight8_frame_000087.jpg
# [OK] Saved Shoplight8_frame_000088.jpg
# [OK] Saved Shoplight8_frame_000089.jpg
# [OK] Saved Shoplight8_frame_000090.jpg
# [OK] Saved Shoplight8_frame_000091.jpg
# [OK] Saved Shoplight8_frame_000092.jpg
# [OK] Saved Shoplight8_frame_000093.jpg
# [OK] Saved Shoplight8_frame_000094.jpg
# [OK] Saved Shoplight8_frame_000095.jpg
# [OK] Saved Shoplight8_frame_000096.jpg
# [OK] Saved Shoplight8_frame_000097.jpg
# [OK] Saved Shoplight8_frame_000098.jpg
# [OK] Saved Shoplight8_frame_000099.jpg
# [OK] Saved Shoplight8_frame_000100.jpg
# [OK] Saved Shoplight8_frame_000101.jpg
# [OK] Saved Shoplight8_frame_000102.jpg
# [OK] Saved Shoplight8_frame_000103.jpg
# [OK] Saved Shoplight8_frame_000104.jpg
# [OK] Saved Shoplight8_frame_000105.jpg
# [OK] Saved Shoplight8_frame_000106.jpg
# [OK] Saved Shoplight8_frame_000107.jpg
# [OK] Saved Shoplight8_frame_000108.jpg
# [OK] Saved Shoplight8_frame_000109.jpg
# [OK] Saved Shoplight8_frame_000110.jpg
# [OK] Saved Shoplight8_frame_000111.jpg
# [OK] Saved Shoplight8_frame_000112.jpg
# [OK] Saved Shoplight8_frame_000113.jpg
# [OK] Saved Shoplight8_frame_000114.jpg
# [OK] Saved Shoplight8_frame_000115.jpg
# [OK] Saved Shoplight8_frame_000116.jpg
# [OK] Saved Shoplight8_frame_000117.jpg
# [OK] Saved Shoplight8_frame_000118.jpg
# [OK] Saved Shoplight8_frame_000119.jpg
# [OK] Saved Shoplight8_frame_000120.jpg
# [OK] Saved Shoplight8_frame_000121.jpg
# [OK] Saved Shoplight8_frame_000122.jpg
# [OK] Saved Shoplight8_frame_000123.jpg
# [OK] Saved Shoplight8_frame_000124.jpg
# [OK] Saved Shoplight8_frame_000125.jpg
# [OK] Saved Shoplight8_frame_000126.jpg
# [OK] Saved Shoplight8_frame_000127.jpg
# [OK] Saved Shoplight8_frame_000128.jpg
# [OK] Saved Shoplight8_frame_000129.jpg
# [OK] Saved Shoplight8_frame_000130.jpg
# [OK] Saved Shoplight8_frame_000131.jpg
# [OK] Saved Shoplight8_frame_000132.jpg
# [OK] Saved Shoplight8_frame_000133.jpg
# [OK] Saved Shoplight8_frame_000134.jpg
# [OK] Saved Shoplight8_frame_000135.jpg
# [OK] Saved Shoplight8_frame_000136.jpg
# [OK] Saved Shoplight8_frame_000137.jpg
# [OK] Saved Shoplight8_frame_000138.jpg
# [OK] Saved Shoplight8_frame_000139.jpg
# [OK] Saved Shoplight8_frame_000140.jpg
# [OK] Saved Shoplight8_frame_000141.jpg
# [OK] Saved Shoplight8_frame_000142.jpg
# [OK] Saved Shoplight8_frame_000143.jpg
# [OK] Saved Shoplight8_frame_000144.jpg
# [OK] Saved Shoplight8_frame_000145.jpg
# [OK] Saved Shoplight8_frame_000146.jpg
# [OK] Saved Shoplight8_frame_000147.jpg
# [OK] Saved Shoplight8_frame_000148.jpg
# [OK] Saved Shoplight8_frame_000149.jpg
# [OK] Saved Shoplight8_frame_000150.jpg
# [OK] Saved Shoplight8_frame_000151.jpg
# [OK] Saved Shoplight8_frame_000152.jpg
# [OK] Saved Shoplight8_frame_000153.jpg
# [OK] Saved Shoplight8_frame_000154.jpg
# [OK] Saved Shoplight8_frame_000155.jpg
# [OK] Saved Shoplight8_frame_000156.jpg
# [OK] Saved Shoplight8_frame_000157.jpg
# [OK] Saved Shoplight8_frame_000158.jpg
# [OK] Saved Shoplight8_frame_000159.jpg
# [OK] Saved Shoplight8_frame_000160.jpg
# [OK] Saved Shoplight8_frame_000161.jpg
# [OK] Saved Shoplight8_frame_000162.jpg
# [OK] Saved Shoplight8_frame_000163.jpg
# [OK] Saved Shoplight8_frame_000164.jpg
# [OK] Saved Shoplight8_frame_000165.jpg
# [OK] Saved Shoplight8_frame_000166.jpg
# [OK] Saved Shoplight8_frame_000167.jpg
# [OK] Saved Shoplight8_frame_000168.jpg
# [OK] Saved Shoplight8_frame_000169.jpg
# [OK] Saved Shoplight8_frame_000170.jpg
# [OK] Saved Shoplight8_frame_000171.jpg
# [OK] Saved Shoplight8_frame_000172.jpg
# [OK] Saved Shoplight8_frame_000173.jpg
# [OK] Saved Shoplight8_frame_000174.jpg
# [OK] Saved Shoplight8_frame_000175.jpg
# [OK] Saved Shoplight8_frame_000176.jpg
# [OK] Saved Shoplight8_frame_000177.jpg
# [OK] Saved Shoplight8_frame_000178.jpg
# [OK] Saved Shoplight8_frame_000179.jpg
# [OK] Saved Shoplight8_frame_000180.jpg
# [OK] Saved Shoplight8_frame_000181.jpg
# [OK] Saved Shoplight8_frame_000182.jpg
# [OK] Saved Shoplight8_frame_000183.jpg
# [OK] Saved Shoplight8_frame_000184.jpg
# [OK] Saved Shoplight8_frame_000185.jpg
# [OK] Saved Shoplight8_frame_000186.jpg
# [OK] Saved Shoplight8_frame_000187.jpg
# [OK] Saved Shoplight8_frame_000188.jpg
# [OK] Saved Shoplight8_frame_000189.jpg
# [OK] Saved Shoplight8_frame_000190.jpg
# [OK] Saved Shoplight8_frame_000191.jpg
# [OK] Saved Shoplight8_frame_000192.jpg
# [OK] Saved Shoplight8_frame_000193.jpg
# [OK] Saved Shoplight8_frame_000194.jpg
# [OK] Saved Shoplight8_frame_000195.jpg
# [OK] Saved Shoplight8_frame_000196.jpg
# [OK] Saved Shoplight8_frame_000197.jpg
# [OK] Saved Shoplight8_frame_000198.jpg
# [OK] Saved Shoplight8_frame_000199.jpg
# [OK] Saved Shoplight8_frame_000200.jpg
# [INFO] No more frames at index 402.
# [DONE] Shoplight8: Total frames read: 402, frames saved: 201
#
# [COMPLETE] All videos have been processed.
